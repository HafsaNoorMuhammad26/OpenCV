# %% [markdown]
# **37_Analyze an Image using Histogram**

# %% [markdown]
# **Image Histogram**
# - It is a plot with pixel values (ranging from 0 to 255, not always) in X-axis and corresponding number of pixels in the image on Y-axis.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
blank_w = np.ones((500,500,3),np.uint8)*255
blank_b = np.zeros((500,500,3),np.uint8)*255

# %%
# hist_w = cv2.calcHist([blank_w],[0],None,[256],[0,256])
# plt.plot(hist_w)
# plt.show()
hist_b = cv2.calcHist([blank_b],[0],None,[256],[0,256])
plt.plot(hist_b)
plt.show()


# cv2.imshow("Blank White", blank_w)
cv2.imshow("Blank Black", blank_b)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(10,10))

img = cv2.imread(r"C:\Users\hp\Documents\jupyter\OpenCV by WsCube Tech\Images\Sana Javaid.jpg")
img = cv2.resize(img, (500,500))

hist = cv2.calcHist([img],[0],None,[256],[0,256])

new = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
hist1 = cv2.calcHist([new],[0],None,[256],[0,256])

plt.subplot(2,1,1)
plt.plot(hist)

plt.subplot(2,1,2)
plt.plot(hist1)

plt.show()

cv2.imshow("Image", img)
cv2.imshow("New", new)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\hp\Documents\jupyter\OpenCV by WsCube Tech\Images\Sana Javaid.jpg")
img = cv2.resize(img, (500,500))

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
b,g,r = cv2.split(img)

hist = cv2.calcHist([b],[0],None,[256],[0,256])
hist_gr = cv2.calcHist([gray],[0],None,[256],[0,256])
hist_b = cv2.calcHist([b],[0],None,[256],[0,256])
hist_g = cv2.calcHist([g],[0],None,[256],[0,256])
hist_r = cv2.calcHist([r],[0],None,[256],[0,256])

# Plot histograms
# plt.figure(figsize=(10, 10))

# plt.subplot(5, 1, 1)
# plt.plot(hist, color='black')
# plt.title("Original Histogram")

# plt.subplot(5, 1, 2)
# plt.plot(hist, color='gray')
# plt.title("Gray Scale Histogram")

# plt.subplot(5, 1, 3)
# plt.plot(hist_b, color='blue')
# plt.title("Blue Channel Histogram")

# plt.subplot(5, 1, 4)
# plt.plot(hist_g, color='green')
# plt.title("Green Channel Histogram")

# plt.subplot(5, 1, 5)
# plt.plot(hist_r, color='red')
# plt.title("Red Channel Histogram")

# plt.tight_layout()
# plt.show()


## OR Combined Histogram

# Plot histograms
plt.figure(figsize=(5,5))

# plt.hist(img.ravel(),255,(0,255))
# plt.hist(gray.ravel(),255,(0,255))
plt.hist(b.ravel(),255,(0,255),color="blue")
plt.hist(g.ravel(),255,(0,255),color="green")
plt.hist(r.ravel(),255,(0,255),color="red")

plt.title("Combined Histogram")

plt.show()

# Show original and channel images
cv2.imshow("Original Image", img)
cv2.imshow("Gray Image", gray)
cv2.imshow("Blue Image", b)
cv2.imshow("Green Image", g)
cv2.imshow("Red Image", r)
cv2.waitKey(0)
cv2.destroyAllWindows()
